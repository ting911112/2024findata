# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ting911112/2024findata/main/BALANCESHEET%20(2).csv"

# %%
df1 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#                YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1234 HEY SONG  2023/12        4             Y     12      NTD
# 1301 FPC       2023/12        4             Y     12      NTD
#
#                Total cash and cash equivalents  \
# CO_ID
# 1234 HEY SONG                        1489381.0
# 1301 FPC                             6147041.0
#
#                Total current financial assets at fair value through profit or loss  \
# CO_ID
# 1234 HEY SONG                                            60101.0
# 1301 FPC                                               1641598.0
#
#                Financial assets at fair value through other comprehensive income - Current  \
# CO_ID
# 1234 HEY SONG                                                0.0
# 1301 FPC                                              90739431.0
#
#                Financial assets measured at amortized cost - Current  \
# CO_ID
# 1234 HEY SONG                                            64837.0
# ...

# %%
url = "https://raw.githubusercontent.com/ting911112/2024findata/main/income_statement2.csv"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#                YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1234 HEY SONG  2023/12        4             Y     12      NTD
# 1301 FPC       2023/12        4             Y     12      NTD
#
#                Gross operating revenue  Total rental revenue  \
# CO_ID
# 1234 HEY SONG               10972964.0                   0.0
# 1301 FPC                   199138777.0                   0.0
#
#                Operating revenue - Disposal of lands  Interest revenue  \
# CO_ID
# 1234 HEY SONG                                    0.0               0.0
# 1301 FPC                                         0.0               0.0
#
#                Operating revenue - disposal of investments  ...  \
# CO_ID                                                       ...
# 1234 HEY SONG                                          0.0  ...
# 1301 FPC                                               0.0  ...
#
#                Preferred stock dividends  Diluted net income  \
# CO_ID
# ...

# %%
df1.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total cash and cash equivalents',
#        'Total current financial assets at fair value through profit or loss',
#        'Financial assets at fair value through other comprehensive income - Current',
#        'Financial assets measured at amortized cost - Current',
#        'Current financial assets for hedging',
#        ...
#        'Other equity - unearned compensation', 'Other equity, others',
#        'Total other equity interest', 'Treasury shares',
#        'Total equity attributable to owners of parent',
#        'Interests in the former associate or jointly controlled entity',
#        'Non-controlling interest in pre-acquisition share capital',
#        'Non-controlling interests', 'Total equity',
#        'Total liabilities & equity'],
#       dtype='object', length=111)

# %%
df1.index
# Out:
# Index(['1234 HEY SONG', '1301 FPC'], dtype='object', name='CO_ID')

# %%
A_1101 = (df1.loc['1234 HEY SONG','Total current assets'] - df1.loc['1234 HEY SONG','Total current liabilities'])/df1.loc['1234 HEY SONG','Total assets']

# %%
A_1101
# Out:
# 0.27880337594069105

# %%
X1 ='Total current assets'
X2 ='Total current liabilities'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Earnings before interest and tax'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Total operating revenue'
HS ='1234 HEY SONG'
FPC ='1301 FPC'

# %%
A_HS = (df1.loc[HS,X1] - df1.loc[HS,X2])/df1.loc[HS, X3]

# %%
B_HS = df1.loc[HS,X4]/df1.loc[HS, X3]

# %%
C_HS = df2.loc[HS,X5]/df1.loc[HS, X3]

# %%
D_HS = df1.loc[HS,X6]/df1.loc[HS, X7]

# %%
E_HS = df2.loc[HS,X8]/df1.loc[HS, X3]

# %%
Z_score_HS = 1.2*A_HS + 1.4*B_HS + 3.3*C_HS + 0.6*D_HS +1.0*E_HS

# %%
Z_score_HS, A_HS, B_HS, C_HS, D_HS, E_HS
# Out:
# (4.575753124718747,
#  0.27880337594069105,
#  0.6295134836792817,
#  0.053285991206413606,
#  4.53221763688716,
#  0.46469584332546265)

# %%
A_FPC = (df1.loc[FPC,X1] - df1.loc[FPC,X2])/df1.loc[FPC, X3]

# %%
B_FPC = df1.loc[FPC,X4]/df1.loc[FPC, X3]

# %%
C_FPC = df2.loc[FPC,X5]/df1.loc[FPC, X3]

# %%
D_FPC = df1.loc[FPC,X6]/df1.loc[FPC, X7]

# %%
E_FPC = df2.loc[FPC,X8]/df1.loc[FPC, X3]

# %%
Z_score_FPC = 1.2*A_FPC + 1.4*B_FPC + 3.3*C_FPC + 0.6*D_FPC +1.0*E_FPC

# %%
Z_score_FPC, A_FPC, B_FPC, C_FPC, D_FPC, E_FPC
# Out:
# (2.252291306806587,
#  0.10652440201627335,
#  0.3971906714803179,
#  0.017165893320135316,
#  1.894228017089773,
#  0.3752108261043036)
